# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

csv_file = '/Users/omaradriannecarpiobapora/Desktop/CS-133/team8-capitalbikeshare-ridership/data/hour.csv'
hour = pd.read_csv(csv_file)

# %%
hour.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  str
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  count       17379 non-null  int64
# dtypes: float64(4), int64(12), str(1)
# memory usage: 2.3 MB

# %%
hour.max()
# Out:
# instant            17379
# dteday        2012-12-31
# season                 4
# yr                     1
# mnth                  12
# hr                    23
# holiday                1
# weekday                6
# workingday             1
# weathersit             4
# temp                 1.0
# atemp                1.0
# hum                  1.0
# windspeed         0.8507
# casual               367
# registered           886
# count                977
# dtype: object

# %%
hour = hour.astype({
    'instant':'int16',
    'season':'int16',
    'yr':'int16',
    'mnth':'int16',
    'hr':'int16',
    'holiday':'int16',
    'weekday':'int16',
    'workingday':'int16',
    'weathersit':'int16',
    'casual':'int16',
    'registered':'int16',
    'count':'int16',
})

# %%
hour.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int16
#  1   dteday      17379 non-null  str
#  2   season      17379 non-null  int16
#  3   yr          17379 non-null  int16
#  4   mnth        17379 non-null  int16
#  5   hr          17379 non-null  int16
#  6   holiday     17379 non-null  int16
#  7   weekday     17379 non-null  int16
#  8   workingday  17379 non-null  int16
#  9   weathersit  17379 non-null  int16
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int16
#  15  registered  17379 non-null  int16
#  16  count       17379 non-null  int16
# dtypes: float64(4), int16(12), str(1)
# memory usage: 1.1 MB

# %%
hour.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  count
# 0           1  0.24  0.2879  0.81        0.0       3          13     16
# 1           1  0.22  0.2727  0.80        0.0       8          32     40
# 2           1  0.22  0.2727  0.80        0.0       5          27     32
# 3           1  0.24  0.2879  0.75        0.0       3          10     13
# 4           1  0.24  0.2879  0.75        0.0       0           1      1

# %%
# Pair plot used for EDA
# g=sns.pairplot(
#     data=hour,
#     kind='reg',
#     plot_kws={'scatter_kws':{'color':'lightgrey', 's':5}},
#     height=1.5
# )
# g.fig.suptitle('Pairwise Relationships in Capital Bikeshare Dataset', y=1.05);

# %%
# Creating a non-numerical season variable
def season_to_string(season):
    if season == 1:
        return 'Winter'
    elif season == 2:
        return 'Spring'
    elif season == 3:
        return 'Summer'
    elif season == 4:
        return 'Fall'
        

hour['season_name'] = hour['season'].map(season_to_string)
display(hour['season_name'].head())
display(hour['season_name'].value_counts())
# Out:
# 0    Winter
# 1    Winter
# 2    Winter
# 3    Winter
# 4    Winter
# Name: season_name, dtype: str
# season_name
# Summer    4496
# Spring    4409
# Winter    4242
# Fall      4232
# Name: count, dtype: int64

# %%
# Small-multiples plot: relplot()
g=sns.relplot(
    data=hour,
    x='hr',
    y='count',
    col='season_name',
    col_wrap=2,
    hue='temp',
    palette='GnBu',
    alpha=0.6,
    height=3
)
g.fig.suptitle('Ridership by Hour', y=1.03);

# %%
# Regression plot (lmplot)
g=sns.lmplot(
    data=hour,
    x='temp',
    y='count',
    scatter_kws={'color':'lightgrey', 'alpha':0.6}
)
g.fig.suptitle('Ridership vs Temperature', y=1.03);

# %%
g=sns.lmplot(
    data=hour,
    x='hum',
    y='count',
    scatter_kws={'color':'lightgrey', 'alpha':0.6}
)
g.fig.suptitle('Ridership vs Humidity', y=1.03);

# %%
# Grouping by date and season for the box plot (avoids plotting too many outliers)
day = hour.groupby(['dteday', 'season_name'])['count'].sum().reset_index()
day.info()
display(day.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dteday       731 non-null    str
#  1   season_name  731 non-null    str
#  2   count        731 non-null    int16
# dtypes: int16(1), str(2)
# memory usage: 13.0 KB
#        dteday season_name  count
# 0  2011-01-01      Winter    985
# 1  2011-01-02      Winter    801
# 2  2011-01-03      Winter   1349
# 3  2011-01-04      Winter   1562
# 4  2011-01-05      Winter   1600

# %%
# Categorical plot: Box Plot
g=sns.catplot(
    data=day,
    kind='box',
    x='count',
    y='season_name',
    showmeans=True,
)
g.fig.suptitle('Daily Ridership by Season (Summary)', y=1.03);

# %%
# Creating a non-numerical weekday variable
def weekday_to_string(weekday):
    if weekday == 6:
        return 'Saturday'
    elif weekday == 0:
        return 'Sunday'
    elif weekday == 1:
        return 'Monday'
    elif weekday == 2:
        return 'Tuesday'
    elif weekday == 3:
        return 'Wednesday'
    elif weekday == 4:
        return 'Thursday'
    elif weekday == 5:
        return 'Friday'
    
hour['weekday_name'] = hour['weekday'].map(weekday_to_string)

display(hour['weekday_name'].head())
display(hour['weekday_name'].value_counts())
# Out:
# 0    Saturday
# 1    Saturday
# 2    Saturday
# 3    Saturday
# 4    Saturday
# Name: weekday_name, dtype: str
# weekday_name
# Saturday     2512
# Sunday       2502
# Friday       2487
# Monday       2479
# Wednesday    2475
# Thursday     2471
# Tuesday      2453
# Name: count, dtype: int64

# %%
# Establishing order among weekday values
from pandas.api.types import CategoricalDtype

# Ordering the days
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Creating ordered categorical type
day_type = CategoricalDtype(categories=days, ordered=True)
hour['weekday_name'] = hour['weekday_name'].astype(day_type)

# %%
# Sanity check for the two newly added columns season_name and weekday_name
hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  count  \
# 0           1  0.24  0.2879  0.81        0.0       3          13     16
# 1           1  0.22  0.2727  0.80        0.0       8          32     40
# 2           1  0.22  0.2727  0.80        0.0       5          27     32
# 3           1  0.24  0.2879  0.75        0.0       3          10     13
# 4           1  0.24  0.2879  0.75        0.0       0           1      1
#
#   season_name weekday_name
# 0      Winter     Saturday
# ...

# %%
# The values for the heatmap
display(hour.groupby(['weekday_name', 'mnth'])['count'].mean())

# DataFrame for our heatmap
hour.groupby(['weekday_name', 'mnth'])['count'].mean().unstack()
# Out:
# weekday_name  mnth
# Monday        1        81.644068
#               2       110.824468
#               3       150.877660
#               4       189.915888
#               5       188.013889
#                          ...
# Sunday        8       203.372973
#               9       256.648148
#               10      197.287037
#               11      171.921875
#               12      114.693023
# Name: count, Length: 84, dtype: float64
# mnth                  1           2           3           4           5   \
# weekday_name
# Monday         81.644068  110.824468  150.877660  189.915888  188.013889
# Tuesday       116.717172  123.453552  149.609302  189.828125  209.375000
# Wednesday      95.050000  119.433962  154.345794  181.397906  213.300926
# Thursday      114.891429  121.841270  160.378151  198.500000  245.527778
# Friday        103.555556  124.813830  165.102804  182.791667  239.625000
# Saturday       82.285047   94.437500  164.115741  185.236111  249.104167
# ...

# %%
# Heatmap plot
plt.figure(figsize=(10, 7))
sns.heatmap(
    data=hour.groupby(['weekday_name', 'mnth'])['count'].mean().unstack(),
    annot=True,
    fmt='.1f',
    cmap='GnBu'
)
plt.title('Average Ridership Count by Weekday and Month')
plt.xlabel('Month', rotation=.5)
plt.ylabel('Weekday')
plt.yticks(rotation=0)
plt.show()

# %%
# Sorting the days by mean and median ridership count in descending order
display(hour.groupby('weekday_name')['count'].mean().sort_values(ascending=False))

hour.groupby('weekday_name')['count'].mean().sort_values(ascending=False)
# Out:
# weekday_name
# Thursday     196.436665
# Friday       196.135907
# Tuesday      191.238891
# Wednesday    191.130505
# Saturday     190.209793
# Monday       183.744655
# Sunday       177.468825
# Name: count, dtype: float64
# weekday_name
# Thursday     196.436665
# Friday       196.135907
# Tuesday      191.238891
# Wednesday    191.130505
# Saturday     190.209793
# Monday       183.744655
# Sunday       177.468825
# Name: count, dtype: float64

# %%
# Correlation matrix plot
corr_matrix = hour.drop(columns=['instant']).select_dtypes(include='number').corr()

def classify_cell(value):
    if value > 0.1 and value < 0.95:
        return f"{value:.2f}"
    else:
        return ""
annot_corr_matrix = corr_matrix.map(classify_cell)

plt.figure(figsize=(10, 7))
sns.heatmap(
    corr_matrix,
    annot=annot_corr_matrix,
    fmt='s',
    cmap=sns.diverging_palette(240, 10, n=15)
)
plt.title('Correlation Matrix')
plt.show()

# %%
ridership_count_corr = hour.corr(numeric_only=True)['count'].sort_values(ascending=False)
corr = ridership_count_corr.drop(['count'])
corr
# Out:
# registered    0.972151
# casual        0.694564
# temp          0.404772
# atemp         0.400929
# hr            0.394071
# instant       0.278379
# yr            0.250495
# season        0.178056
# mnth          0.120638
# windspeed     0.093234
# workingday    0.030284
# weekday       0.026900
# holiday      -0.030927
# weathersit   -0.142426
# hum          -0.322911
# Name: count, dtype: float64

# %%
plt.figure(figsize=(6,8))

corr = corr.drop(['registered', 'casual', 'instant'])
sns.barplot(
    x=corr.values,
    y=corr.index,
    palette='viridis'
)

plt.title('Correlation with Ridership Count')
plt.xlabel('Correlation')
plt.ylabel('Features')
plt.show()
# Out:
# /var/folders/l7/wdshbjp17ng0_0nvvkv1m6jc0000gn/T/ipykernel_41345/1647849028.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Using melt to prepare our line plot data
melted_hour = hour.melt(
    id_vars=[col for col in hour.columns if col not in ['registered', 'casual']],
    var_name='rider_status',
    value_name='ridership_count'
)
melted_hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 34753    17375  2012-12-31       1   1    12  19        0        1
# 34754    17376  2012-12-31       1   1    12  20        0        1
# 34755    17377  2012-12-31       1   1    12  21        0        1
# 34756    17378  2012-12-31       1   1    12  22        0        1
# 34757    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  count  \
# 0               0           1  0.24  0.2879  0.81     0.0000     16
# ...

# %%
# Ridership by registered status DataFrame
melted_day = melted_hour.groupby(['dteday', 'weekday_name', 'rider_status'])['ridership_count'].sum().reset_index()
melted_day
# Out:
#           dteday weekday_name rider_status  ridership_count
# 0     2011-01-01     Saturday       casual              331
# 1     2011-01-01     Saturday   registered              654
# 2     2011-01-02       Sunday       casual              131
# 3     2011-01-02       Sunday   registered              670
# 4     2011-01-03       Monday       casual              120
# ...          ...          ...          ...              ...
# 1457  2012-12-29     Saturday   registered             1182
# 1458  2012-12-30       Sunday       casual              364
# 1459  2012-12-30       Sunday   registered             1432
# 1460  2012-12-31       Monday       casual              439
# 1461  2012-12-31       Monday   registered             2290
#
# [1462 rows x 4 columns]

# %%
# Interactive line plot
import plotly.express as px

line_plot = px.line(
    melted_day,
    x='dteday',
    y='ridership_count',
    color='rider_status',
    line_dash='rider_status',
    title='Registered vs Casual Ridership'
)

line_plot.show()

# %%
grouped_by_day_melted_day = melted_day.groupby(['weekday_name', 'rider_status'])['ridership_count'].sum().reset_index()
grouped_by_day_melted_day
# Out:
#    weekday_name rider_status  ridership_count
# 0        Monday       casual            70784
# 1        Monday   registered           384719
# 2       Tuesday       casual            57843
# 3       Tuesday   registered           411266
# 4     Wednesday       casual            57319
# 5     Wednesday   registered           415729
# 6      Thursday       casual            61460
# 7      Thursday   registered           423935
# 8        Friday       casual            78238
# 9        Friday   registered           409552
# 10     Saturday       casual           153852
# 11     Saturday   registered           323955
# 12       Sunday       casual           140521
# 13       Sunday   registered           303506

# %%
# Interactive bar plot (stacked)
bar_plot = px.bar(
    grouped_by_day_melted_day,
    x='weekday_name',
    y='ridership_count',
    color='rider_status',
    title='Ridership by Weekday'
)
bar_plot.show()

# %%
# Registered user ridership percentage
grouped_by_rider_status_melted_day = melted_day.groupby(['rider_status'])['ridership_count'].sum()
percentage_of_registered = grouped_by_rider_status_melted_day.loc['registered'] / hour['count'].sum()
print(f'Proportion of registered users: {percentage_of_registered}')

# Alternatively
hour['registered'].sum() / hour['count'].sum()
# Out:
# Proportion of registered users: 0.8116983161735475
# np.float64(0.8116983161735475)
